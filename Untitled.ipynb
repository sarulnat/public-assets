# %%
import json

# Opening JSON file
f = open("ItemsForDiffusion.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# start with prodct classes
allNames = []
allID = []
for k in data['data']['flows']:
    allNames.append(k['basename']+" "+k['feature']+" "+k['description'])
    allID.append(k['_id'])
    #print(k)
for i in data['data']['products']:
    allNames.append(i['className'])
    allID.append(i['_id'])
    #print(i)

#making name aliases
allNameAlias = ['weather and daylight climate control schedule heating and cooling',
                'privacy room secured in your office',
                'climate control blinds according to daylight patterns',
                'calendar morning wake up call',
                'bed weight sensor',
                'motivational videos morning waking up',
                'home outdoor lights',
                'fix energy leaks',
                'leaving home doors',
                'private room door control',
                'leaving home cameras',
                'television and music everywhere at home',
                'lights triggered cameras',
                'private room mute ',
                'do not disturb private room',
                'energy usage alerts on your smartphone for notifications',
                'lights daylight time',
                'automatic light control with a single remote',
                'climate control geolocation',
                'music follow me',
                'morning alarm',
                'morning coffee',
                'leaving home routine, lights, indoor heating cooling',
                'leaving home security ',
                'privacy spy jammer',
                'CHANGE CHANGE CHANGE',
                'entertainment projector curtains and temperature',
                'CHANGE CHANGE CHANGE',
                'infrared receiver',
                'smart light switch',
                'connected camera',
                'motion sensor',
                'smart plugs',
                'noise sensor',
                'red computer button',
                'fingerprint sensor',
                'ledger hardware wallet',
                'weight sensor',
                'smart doorbell',
                'smart thermostat',
                'door opener',
                'smart gas detector',
                'smart pet feeder',
                'raspberry-pi or linux machine',
                'smart light strip',
                'energy monitor',
                'security alarm',
                'near field communication tags',
                'smart door lock',
                'window slider',
                'home plants',
                'future televisions',
                'camera/motion sensor',
                'bed weight sensor',
                'curtain opener',
                'smart speaker']
    

print(allNames)
print(allID)
print(len(allID))


    #generate array of keyword and id
    
#add initial experimentals
#add home rooms for landing page photos
newNames = ["a painting of a wide landscape of smart cities, extreme details, photorealistic, in the style of Frank Gehry, octane render, 8K",
           "hyper realistic photograph of smart city with future transportation, cyberpunk, in the style of Frank Gehry, octane render",
           smart home rooms,
           house on lot of land,
           tall apartment,
            future smart home remote,
            privacy, cybersecurity
           ]
newID = ["smart cities", "smart city cyber punk]
    
# Closing file
f.close()
# Out:
# ['climate control BASE schedule heating & cooling based on weather and daylight', 'private-room BASE setup a privacy mode for your office', 'climate control blinds control your blinds according to daylight patterns to save on heating', 'wake up call 5-day-schedule customize your morning alarm', 'wake up call bed-weight Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.', 'wake up call motivational-media Lorem ipsum dolor sit amet', 'leaving home lights Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.', 'fix energy leaks fix-leaks Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labor
# ...
